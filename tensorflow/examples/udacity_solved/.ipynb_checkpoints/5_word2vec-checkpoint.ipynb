# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

% matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3081, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print('%d -> %d' % (batch[i], labels[i, 0]))
  print('%s -> %s' % (reverse_dictionary[batch[i]],
                      reverse_dictionary[labels[i, 0]]))
# Out:
# 3081 -> 12
# originated -> as
# 3081 -> 5243
# originated -> anarchism
# 12 -> 3081
# as -> originated
# 12 -> 6
# as -> a
# 6 -> 12
# a -> as
# 6 -> 195
# a -> term
# 195 -> 2
# term -> of
# 195 -> 6
# term -> a

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.392366
# Nearest to many: server, demi, dimers, account, midst, marathon, favoured, harris,
# Nearest to not: are, hydrochloric, coppola, medicine, ttt, macho, ascribe, despair,
# Nearest to were: transliterations, mauritians, waterman, rockers, emulator, spitting, primarily, ousted,
# Nearest to other: sines, aaa, pero, mourners, empirically, engagement, parisians, constituents,
# Nearest to first: gabor, enthusiastically, maxime, sackville, shortcomings, spiny, sarcophagi, salman,
# Nearest to most: reconnection, reforestation, turnbull, william, file, polygamy, pheromones, suns,
# Nearest to had: functionalism, reliever, realised, recompense, consider, gavin, morgan, mendelian,
# Nearest to would: irritate, cerrado, jing, moratorium, muppets, stopped, hypothermia, alarming,
# Nearest to that: outreach, effendi, broadly, m, windsurfing, gk, nasr, obrenovi,
# Nearest to be: usual, wastes, transnistria, eridanus, solidify, dagestan, stealing, goku,
# Nearest to have: survived, pence, secured, warcraft, groundwork, buys, russell, courier,
# Nearest to history: barrister, nonstop, unfettered, byelorussia, subdue, adlai, andrei, nag,
# Nearest to after: fails, sasson, nakano, asians, wheeled, catnip, altos, plain,
# Nearest to however: impervious, bute, turnips, harmonising, injecting, kitab, escalation, enlarging,
# Nearest to during: achieved, aasen, purporting, sleeping, appalachian, wrongful, paphos, yudhoyono,
# Nearest to i: proleptic, superiority, scores, subunit, midian, banzer, combatants, barrington,
# Average loss at step 2000: 4.362451
# Average loss at step 4000: 3.870485
# Average loss at step 6000: 3.784841
# Average loss at step 8000: 3.688529
# Average loss at step 10000: 3.616323
# Nearest to many: some, masterpieces, gestae, latent, wimp, such, state, server,
# Nearest to not: it, filmfour, they, paw, who, there, we, conformist,
# Nearest to were: are, was, emulator, be, is, have, hindemith, naps,
# Nearest to other: borealis, some, reflectance, dribbling, acclaim, un, instigation, metastability,
# Nearest to first: barrows, british, hip, tilted, lamar, promulgate, provability, biographers,
# Nearest to most: last, candela, contending, erik, sixty, substituents, yoke, secondo,
# Nearest to had: has, have, was, realised, reliever, admired, scanned, kutch,
# Nearest to would: can, censuses, statically, will, may, mule, to, could,
# Nearest to that: which, it, if, seize, who, this, pentium, he,
# Nearest to be: have, furlong, was, were, are, by, is, accountants,
# Nearest to have: had, has, be, are, nowy, were, expended, dear,
# Nearest to history: nonstop, barrister, german, adlai, transgression, flattening, proof, squaw,
# Nearest to after: sasson, daryl, camps, buffer, for, nansen, mgh, encouraging,
# Nearest to however: weiner, but, emi, fellow, purify, turnips, may, saintly,
# Nearest to during: aasen, oa, cathy, flashback, at, sleeping, on, perched,
# Nearest to i: subunit, unintelligible, scores, risorgimento, publicist, outsourcing, lapse, they,
# Average loss at step 12000: 3.605722
# Average loss at step 14000: 3.572065
# Average loss at step 16000: 3.410968
# Average loss at step 18000: 3.457487
# Average loss at step 20000: 3.538340
# Nearest to many: some, several, all, other, these, such, masterpieces, reintroducing,
# Nearest to not: also, it, generally, still, uhf, they, filmfour, to,
# Nearest to were: are, was, have, be, had, is, by, being,
# Nearest to other: many, some, sides, dribbling, peerages, westview, places, such,
# Nearest to first: second, puzo, wuhan, hip, barrows, british, last, hague,
# Nearest to most: more, last, secondo, breeds, some, lain, substituents, erik,
# Nearest to had: has, have, was, realised, were, reliever, having, admired,
# Nearest to would: can, will, may, could, might, mule, must, statically,
# Nearest to that: which, contests, seize, however, ado, it, this, obrenovi,
# Nearest to be: were, is, was, by, been, have, take, furlong,
# Nearest to have: had, has, were, are, be, contend, teach, regimes,
# Nearest to history: flattening, number, general, showa, barrister, supergroup, mendelian, nonstop,
# Nearest to after: sasson, before, from, during, inversely, daryl, buffer, lanthanides,
# Nearest to however: but, fellow, that, emi, weiner, civilian, although, approximated,
# Nearest to during: aasen, after, oa, cathy, flashback, under, in, designator,
# Nearest to i: ii, unintelligible, outsourcing, we, subunit, scores, satisfy, lapse,
# Average loss at step 22000: 3.501215
# Average loss at step 24000: 3.489064
# Average loss at step 26000: 3.479307
# Average loss at step 28000: 3.478323
# Average loss at step 30000: 3.503733
# Nearest to many: some, several, these, other, all, delusions, the, breeds,
# Nearest to not: still, generally, they, it, tamarin, operators, paw, also,
# Nearest to were: are, was, have, had, be, goodall, by, is,
# Nearest to other: some, many, such, these, abroad, facilitate, reflectance, peerages,
# Nearest to first: second, next, same, last, adamic, biographers, allergic, alps,
# Nearest to most: more, annotations, lain, use, secondo, some, breeds, many,
# Nearest to had: have, has, was, were, realised, reliever, having, tolson,
# Nearest to would: can, will, could, may, might, must, should, shall,
# Nearest to that: which, what, this, however, but, if, seize, iia,
# Nearest to be: have, is, been, furlong, are, were, slovakian, refer,
# Nearest to have: had, has, are, were, be, having, teach, never,
# Nearest to history: mendelian, showa, phage, cooperated, number, development, predictability, commerce,
# Nearest to after: before, during, when, sasson, inversely, from, climber, constitute,
# Nearest to however: but, although, that, weiner, while, approximated, emi, and,
# Nearest to during: after, in, aasen, at, until, under, when, before,
# Nearest to i: ii, unintelligible, we, satisfy, scores, subunit, outsourcing, xing,
# Average loss at step 32000: 3.503965
# Average loss at step 34000: 3.492566
# Average loss at step 36000: 3.455187
# Average loss at step 38000: 3.302641
# Average loss at step 40000: 3.423541
# Nearest to many: some, several, these, other, various, those, all, such,
# Nearest to not: they, still, generally, so, always, it, paw, also,
# Nearest to were: are, have, was, had, being, be, hort, these,
# Nearest to other: some, many, different, abroad, several, distinct, competing, seller,
# Nearest to first: second, last, next, wuhan, same, allergic, reintroduce, barrows,
# Nearest to most: more, some, annotations, lain, secondo, many, breeds, erik,
# Nearest to had: has, have, was, were, capuchin, realised, having, tolson,
# Nearest to would: will, can, could, may, might, must, should, did,
# Nearest to that: which, however, what, this, it, iia, but, trilogy,
# Nearest to be: have, been, are, furlong, were, being, serve, is,
# Nearest to have: has, had, were, are, be, having, teach, isabel,
# Nearest to history: mendelian, development, list, cooperated, affectation, proof, side, raskin,
# Nearest to after: before, during, sasson, when, from, thousandth, inversely, crick,
# Nearest to however: but, although, that, while, though, weiner, banach, walruses,
# Nearest to during: after, since, under, at, when, against, on, until,
# Nearest to i: ii, we, he, unintelligible, outsourcing, they, satisfy, xing,
# Average loss at step 42000: 3.435140
# Average loss at step 44000: 3.456416
# Average loss at step 46000: 3.452133
# Average loss at step 48000: 3.351945
# Average loss at step 50000: 3.383048
# Nearest to many: some, several, these, various, those, both, all, other,
# Nearest to not: still, generally, always, filmfour, really, who, usually, paw,
# Nearest to were: are, was, have, had, be, been, being, although,
# Nearest to other: different, some, many, various, dwellers, several, disturbance, including,
# Nearest to first: last, second, next, same, wuhan, allergic, third, bangui,
# Nearest to most: more, lain, some, less, many, last, use, annotations,
# Nearest to had: has, have, was, having, were, realised, capuchin, wanted,
# Nearest to would: will, could, can, may, might, must, should, did,
# Nearest to that: which, however, what, this, refracting, but, incensed, seize,
# Nearest to be: have, were, furlong, being, been, become, was, are,
# Nearest to have: had, has, were, be, are, having, isabel, produce,
# Nearest to history: raskin, affectation, list, phage, showa, proof, anglicisation, cooperated,
# Nearest to after: before, during, when, sasson, while, but, inversely, from,
# Nearest to however: but, although, while, that, though, when, where, weiner,
# Nearest to during: after, under, when, in, at, before, since, from,
# Nearest to i: we, ii, you, unintelligible, xing, outsourcing, t, he,
# Average loss at step 52000: 3.436773
# Average loss at step 54000: 3.426733
# Average loss at step 56000: 3.438307
# Average loss at step 58000: 3.397021
# Average loss at step 60000: 3.391772
# Nearest to many: some, several, these, various, all, other, those, most,
# Nearest to not: still, usually, filmfour, generally, now, typically, they, really,
# Nearest to were: are, have, had, was, although, be, including, been,
# Nearest to other: different, many, including, various, several, abroad, distinct, tangent,
# Nearest to first: last, second, next, same, wuhan, bpm, reintroduce, only,
# Nearest to most: more, many, lain, use, some, less, last, tutors,
# Nearest to had: has, have, was, were, having, received, tolson, never,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to that: which, what, however, this, iia, encampments, framed, pluriform,
# Nearest to be: been, have, furlong, were, become, provide, are, was,
# Nearest to have: has, had, were, are, having, be, produce, vla,
# Nearest to history: list, raskin, encyclopedia, blackjack, readable, philosophy, teas, geographic,
# Nearest to after: before, during, when, sasson, inversely, while, following, under,
# Nearest to however: but, although, that, though, which, weiner, before, when,
# Nearest to during: after, before, when, under, although, until, since, despite,
# Nearest to i: ii, we, you, unintelligible, amounting, he, t, xing,
# Average loss at step 62000: 3.242048
# Average loss at step 64000: 3.256266
# Average loss at step 66000: 3.405443
# Average loss at step 68000: 3.391231
# Average loss at step 70000: 3.359224
# Nearest to many: some, several, various, these, all, most, those, scholars,
# Nearest to not: now, still, filmfour, almost, always, never, generally, usually,
# Nearest to were: are, have, had, was, be, been, bukhari, including,
# Nearest to other: different, including, technical, various, sed, many, distinct, microscopic,
# Nearest to first: second, last, next, same, third, reintroduce, wuhan, fourth,
# Nearest to most: more, many, less, some, use, ancestor, mimi, exposition,
# Nearest to had: has, have, was, were, having, realised, wanted, capuchin,
# Nearest to would: will, could, may, can, might, must, should, shall,
# Nearest to that: which, however, what, this, iia, but, assertions, obrenovi,
# Nearest to be: been, become, were, is, being, have, furlong, provide,
# Nearest to have: had, has, were, are, having, be, include, provide,
# Nearest to history: list, geographic, raskin, belfry, identifying, breakup, encyclopedia, version,
# Nearest to after: before, during, when, sasson, following, while, at, without,
# Nearest to however: but, although, while, though, that, where, which, before,
# Nearest to during: after, before, in, until, when, although, under, through,
# Nearest to i: ii, we, you, unintelligible, t, g, amounting, colic,
# Average loss at step 72000: 3.373181
# Average loss at step 74000: 3.347566
# Average loss at step 76000: 3.309821
# Average loss at step 78000: 3.353833
# Average loss at step 80000: 3.379734
# Nearest to many: some, several, various, these, most, all, both, those,
# Nearest to not: still, almost, usually, generally, now, always, never, typically,
# Nearest to were: are, was, had, have, been, bleue, be, although,
# Nearest to other: various, including, many, different, falwell, others, peerages, some,
# Nearest to first: last, second, next, same, third, only, fourth, reintroduce,
# Nearest to most: more, many, some, less, mimi, exposition, lain, processor,
# Nearest to had: has, have, was, having, were, wanted, realised, constitute,
# Nearest to would: will, could, may, might, can, must, should, cannot,
# Nearest to that: which, however, what, where, coeducational, this, obrenovi, marek,
# Nearest to be: been, become, being, have, furlong, were, is, conquer,
# Nearest to have: had, has, were, are, having, be, include, provide,
# Nearest to history: list, habibullah, version, searchers, breakup, encyclopedia, geographic, lindy,
# Nearest to after: before, during, when, without, following, while, sasson, despite,
# Nearest to however: although, but, that, though, while, where, especially, polls,
# Nearest to during: after, when, before, in, despite, until, through, although,
# Nearest to i: ii, we, unintelligible, iii, t, you, claudius, warden,
# Average loss at step 82000: 3.409320
# Average loss at step 84000: 3.410394
# Average loss at step 86000: 3.384698
# Average loss at step 88000: 3.347956
# Average loss at step 90000: 3.365008
# Nearest to many: some, several, various, these, all, most, those, certain,
# Nearest to not: still, almost, generally, now, we, actually, usually, only,
# Nearest to were: are, had, have, was, while, although, been, including,
# Nearest to other: various, individual, including, different, most, technical, postgresql, sed,
# Nearest to first: second, last, next, same, dum, reintroduce, fourth, third,
# Nearest to most: more, many, some, less, belgrade, particularly, leucippus, other,
# Nearest to had: has, have, was, were, having, wanted, never, constitute,
# Nearest to would: will, could, might, can, may, must, should, cannot,
# Nearest to that: which, however, what, where, encampments, but, framed, vitellius,
# Nearest to be: been, become, have, conquer, was, is, being, afford,
# Nearest to have: had, has, were, having, are, be, yet, provide,
# Nearest to history: list, habibullah, searchers, version, breakup, geographic, lindy, encyclopedia,
# Nearest to after: before, during, when, without, while, following, at, until,
# Nearest to however: although, but, though, that, where, while, conceits, since,
# Nearest to during: after, through, before, in, until, while, at, when,
# Nearest to i: we, ii, you, t, iii, v, p, differently,
# Average loss at step 92000: 3.395953
# Average loss at step 94000: 3.256419
# Average loss at step 96000: 3.358896
# Average loss at step 98000: 3.243297
# Average loss at step 100000: 3.357312
# Nearest to many: several, some, various, these, all, most, those, few,
# Nearest to not: almost, still, now, never, generally, actually, t, usually,
# Nearest to were: are, have, was, had, these, although, be, bombs,
# Nearest to other: various, others, different, individual, neighboring, vitreous, falwell, including,
# Nearest to first: last, second, next, fourth, third, same, debut, final,
# Nearest to most: more, less, many, particularly, use, especially, some, besieging,
# Nearest to had: has, have, having, wanted, was, were, since, never,
# Nearest to would: will, could, might, can, may, should, must, cannot,
# Nearest to that: which, however, what, framed, but, whom, where, this,
# Nearest to be: been, become, have, are, is, afford, being, refer,
# Nearest to have: had, has, were, are, be, provide, include, having,
# Nearest to history: list, habibullah, geographic, identifying, breakup, lindy, sediment, origins,
# Nearest to after: before, during, when, without, following, despite, qa, while,
# Nearest to however: although, but, that, though, especially, where, conceits, amphitheatre,
# Nearest to during: after, in, through, before, until, despite, when, at,
# Nearest to i: we, ii, you, iii, t, differently, they, v,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    tmp_array = np.array(buffer)
    batch[i, :] = np.concatenate((tmp_array[:skip_window], tmp_array[skip_window+1:]))
    labels[i, 0] = buffer[skip_window]
 
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, skip_window=1)
for i in range(8):
  reverse_batch = np.array([reverse_dictionary[j] for j in batch[i]])
  reverse_label = reverse_dictionary[labels[i, 0]]

  print('%s -> %d' % (batch[i, :], labels[i, 0]))
  print('%s -> %s' % (reverse_batch,
                      reverse_label))
# Out:
# [5243   12] -> 3081
# ['anarchism' 'as'] -> originated
# [3081    6] -> 12
# ['originated' 'a'] -> as
# [ 12 195] -> 6
# ['as' 'term'] -> a
# [6 2] -> 195
# ['a' 'of'] -> term
# [ 195 3135] -> 2
# ['term' 'abuse'] -> of
# [ 2 46] -> 3135
# ['of' 'first'] -> abuse
# [3135   59] -> 46
# ['abuse' 'used'] -> first
# [ 46 156] -> 59
# ['first' 'against'] -> used

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed_extended = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_mean(embed_extended, 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdamOptimizer().minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("Mean:0", shape=TensorShape([Dimension(128), Dimension(128)]), dtype=float32)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.865920
# Nearest to such: maimon, apollinaire, escape, berthold, adhering, ovaries, prerequisites, medicaid,
# Nearest to when: hysterical, wallets, singles, mahmud, surprising, formula, scots, jumper,
# Nearest to he: lossy, tendons, sudden, pogrom, falla, cr, surviving, david,
# Nearest to these: dendrites, segregated, klein, abdal, frowned, phagspa, extractive, solubility,
# Nearest to up: higgs, pollution, whist, demonstrate, islands, winger, papadopoulos, indebted,
# Nearest to people: capsules, webzine, slavonic, physics, raw, chromatic, fetuses, sympathizer,
# Nearest to while: obstructing, banaba, dependable, urbe, speller, tachi, adiabatic, unsatisfied,
# Nearest to th: glace, jadavpur, herd, tapering, joris, cashier, apcs, pursuits,
# Nearest to in: eschewed, drumming, unspecific, gentler, vinci, princesses, opiate, welterweight,
# Nearest to some: gutman, rooting, chestnuts, soundtracks, cobol, gator, underneath, clockwise,
# Nearest to years: eritreans, probate, namesake, sturdy, kharkov, asymmetrical, screech, qcd,
# Nearest to two: pennsylvania, fare, overseen, phony, dx, audition, camilla, elves,
# Nearest to all: pane, synthetically, merrill, rejoiced, hic, soninke, typeface, wheelock,
# Nearest to by: gb, portillo, clc, classis, questioning, throats, variability, tiny,
# Nearest to it: searle, livres, durable, drainage, meredith, utc, granting, kapital,
# Nearest to UNK: territories, vilified, supplementation, dhimma, sais, godly, repudiating, knocks,
# Average loss at step 2000: 5.263746
# Average loss at step 4000: 3.773631
# Average loss at step 6000: 3.399345
# Average loss at step 8000: 3.291449
# Average loss at step 10000: 3.265672
# Nearest to such: adhering, ovaries, fanning, possible, seen, radians, ashore, cans,
# Nearest to when: horses, if, though, theophrastus, renders, huge, explains, lavon,
# Nearest to he: she, they, it, who, briefly, cr, blight, homeschool,
# Nearest to these: dendrites, yellowish, the, censors, warn, seater, inflammation, flexibility,
# Nearest to up: rational, catch, demonstrate, preserving, winger, apart, pollution, dallas,
# Nearest to people: physics, sects, direction, webzine, rare, departure, top, permanent,
# Nearest to while: although, through, until, adiabatic, dialects, insisted, obtained, dystopia,
# Nearest to th: twentieth, three, nd, nine, bc, ample, joris, rd,
# Nearest to in: eschewed, during, creole, upon, drumming, including, unspecific, into,
# Nearest to some: many, its, consciousness, rooting, his, going, intellectual, types,
# Nearest to years: five, days, brushing, mp, beauty, times, miles, rard,
# Nearest to two: nine, four, thirty, three, minutes, million, one, eight,
# Nearest to all: sniper, type, soninke, phrase, going, merrill, archetype, emerged,
# Nearest to by: reunion, questioning, zealots, biotechnology, among, tats, ensue, duodenum,
# Nearest to it: he, who, mean, deeply, durable, they, searle, soon,
# Nearest to UNK: r, territories, f, credit, rom, si, j, h,
# Average loss at step 12000: 3.206815
# Average loss at step 14000: 3.200939
# Average loss at step 16000: 3.170563
# Average loss at step 18000: 3.023244
# Average loss at step 20000: 3.110475
# Nearest to such: adhering, radians, injected, seen, bremerhaven, ashore, counterproductive, possible,
# Nearest to when: if, though, hysterical, perutz, gallop, before, revolutionized, namco,
# Nearest to he: she, they, it, who, originally, blight, briefly, truro,
# Nearest to these: some, censors, reigns, numbers, dendrites, gauls, mattingly, seater,
# Nearest to up: catch, apart, contemporaneous, definitively, pollution, tide, rational, dallas,
# Nearest to people: copies, sects, webzine, conclusions, departure, predators, direction, angelo,
# Nearest to while: although, pumping, through, deniers, until, insisted, wartburg, koine,
# Nearest to th: twentieth, rd, nd, bc, seventeenth, joris, ample, irene,
# Nearest to in: during, drumming, creole, shoulders, helix, feudal, until, asexually,
# Nearest to some: many, several, these, types, its, cobol, intellectual, rooting,
# Nearest to years: days, times, decades, inches, weeks, mp, miles, months,
# Nearest to two: four, three, minutes, nine, thirty, one, meters, helaman,
# Nearest to all: soninke, sniper, accompanies, hamill, sections, both, merrill, typeface,
# Nearest to by: reunion, zealots, tats, questioning, biotechnology, clc, ensue, tiny,
# Nearest to it: he, she, mean, this, deeply, unclear, utc, searle,
# Nearest to UNK: r, si, j, des, h, les, de, el,
# Average loss at step 22000: 3.036895
# Average loss at step 24000: 3.011050
# Average loss at step 26000: 3.024377
# Average loss at step 28000: 2.998229
# Average loss at step 30000: 2.803183
# Nearest to such: injected, counterproductive, seen, bremerhaven, radians, follows, regarded, adhering,
# Nearest to when: if, though, before, during, gallop, whenever, namco, hysterical,
# Nearest to he: she, it, they, who, briefly, originally, blight, eventually,
# Nearest to these: some, censors, reigns, gauls, diverged, futures, numbers, such,
# Nearest to up: catch, out, contemporaneous, apart, tide, down, definitively, off,
# Nearest to people: copies, sects, conclusions, predators, departure, fans, residents, pakistani,
# Nearest to while: although, deniers, cacti, pumping, through, dec, wartburg, insisted,
# Nearest to th: twentieth, seventeenth, ample, joris, nineteenth, bc, seventh, rd,
# Nearest to in: during, within, on, creole, until, despite, drumming, throughout,
# Nearest to some: many, several, these, types, lps, cobol, rooting, accidents,
# Nearest to years: days, decades, times, weeks, months, hours, inches, miles,
# Nearest to two: three, four, one, thirty, nine, seven, minutes, metres,
# Nearest to all: both, soninke, typeface, builders, accompanies, hamill, egoism, exclusively,
# Nearest to by: reunion, zealots, tats, newly, maastricht, plus, duodenum, havel,
# Nearest to it: he, she, this, unclear, unlikely, deeply, there, evolution,
# Nearest to UNK: si, stewart, nuevo, van, ren, el, kelly, la,
# Average loss at step 32000: 2.962139
# Average loss at step 34000: 2.940662
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-fc4d6027e20b> in <module>()
#       8     batch_data, batch_labels = generate_batch(batch_size, skip_window)
#       9     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 10     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      11     average_loss += l
#      12     if step % 2000 == 0:
#
# /home/diogo/bin/anaconda3/lib/python3.4/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict)
#     366
#     367     # Run request and get response.
# --> 368     results = self._do_run(target_list, unique_fetch_targets, feed_dict_string)
#     369
#     370     # User may have fetched the same tensor multiple times, but we
#
# /home/diogo/bin/anaconda3/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_run(self, target_list, fetch_list, feed_dict)
#     426
#     427       return tf_session.TF_Run(self._session, feed_dict, fetch_list,
# --> 428                                target_list)
#     429
#     430     except tf_session.StatusNotOK as e:
#
# KeyboardInterrupt:
